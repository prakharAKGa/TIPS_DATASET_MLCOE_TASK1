# %%
#Tips Dataset for beginners

#One waiter recorded information about each tip he received over a few months of
#working in one restaurant. In all, he recorded 244 tips.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')

# %%
tips = pd.read_csv(r"C:\Users\wwwpr\Downloads\tips.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
avg_tip=tips.tip.mean()

# %%
print("Average tip received by waiter is : {}".format(avg_tip))
# Out:
# Average tip received by waiter is : 2.99827868852459

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 115       17.31  3.50  Female     No   Sun  Dinner     2
# 112       38.07  4.00    Male     No   Sun  Dinner     3
# 36        16.31  2.00    Male     No   Sat  Dinner     3
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4

# %%
tip_sex=pd.pivot_table(tips,index=["sex","smoker"])
# Out:
# C:\Users\wwwpr\AppData\Local\Temp\ipykernel_11356\855786981.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   tip_sex=pd.pivot_table(tips,index=["sex","smoker"])

# %%
tip_sex
# Out:
#                    size       tip  total_bill
# sex    smoker
# Female No      2.592593  2.773519   18.105185
#        Yes     2.242424  2.931515   17.977879
# Male   No      2.711340  3.113402   19.791237
#        Yes     2.500000  3.051167   22.284500

# %%
tip2=pd.pivot_table(tips,index=["day","smoker"],values=["tip","total_bill"],columns="time")
tip2
# Out:
#                   tip           total_bill
# time           Dinner     Lunch     Dinner      Lunch
# day  smoker
# Fri  No      2.750000  3.000000  19.233333  15.980000
#      Yes     3.003333  2.280000  19.806667  12.323333
# Sat  No      3.102889       NaN  19.661778        NaN
#      Yes     2.875476       NaN  21.276667        NaN
# Sun  No      3.167895       NaN  20.506667        NaN
#      Yes     3.516842       NaN  24.120000        NaN
# Thur No      3.000000  2.666364  18.780000  17.075227
#      Yes          NaN  3.030000        NaN  19.190588

# %%
#if we want to look the days when the waiter got the tip greater than 2

# %%
high_tip=tips.tip>2

# %%
tips[high_tip]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [166 rows x 7 columns]

# %%
###which are 10 days at which highest bill paid??

# %%
tips.sort_values('total_bill',ascending = False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
##which are 10 days at which lowest bill paid??

# %%
tips.sort_values('total_bill').head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# 126        8.52  1.48    Male     No  Thur   Lunch     2

# %%
tips.total_bill.plot();

# %%
tips.tip.plot();

# %%
plt.figure(figsize=(20,12))

plt.plot(tips.total_bill,'o--b');
plt.plot(tips.tip,'s-r')
plt.ylabel('total_bill')
plt.legend(['total_bill','tip'])

# %%
sns.scatterplot(x=tips.day,
               y=tips.tip,hue=tips.sex,
               s=200);

# %%
##HISTOGRAM

# %%
plt.title("DISTRIBUTION OF TOTAL BILL AND TIP")
plt.hist(tips.total_bill,alpha=0.4)
plt.hist(tips.tip,alpha=0.4)
plt.legend(['total_bill','tip'])

# %%
##if we want to visualize how the avg. bill amount varies across diff. days

# %%
sns.barplot(x='day',y='total_bill',hue='time',data=tips);

# %%
#here is single grid showing different types of charts

# %%
fig, axes =plt.subplots(2,3, figsize=(16,8))
plt.tight_layout(pad=2)


#day vs total bill


axes[0,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='smoker', data=tips, ax=axes[0,0]);

#Total bill vs total tip

axes[0,1].set_title('Total Bill vs. Total Tip')
sns.scatterplot(x=tips.total_bill, 
                y=tips.tip, 
                hue=tips.sex, 
                s=100, 
                ax=axes[0,1]);


#total bill and tip vs day

axes[0,2].plot(tips.day,tips.total_bill, 'X--b')
axes[0,2].plot(tips.day,tips.tip, 'o--r')
axes[0,2].set_xlabel('DAY')
axes[0,2].set_ylabel('BILL(Rs.)')
axes[0,2].legend(['TOTAL_BILL', 'TIP']);
axes[0,2].set_title('GRAPH OF TOTAL BILL AND TIP');



#total bill and day and size

sns.barplot(x='day', y='total_bill', hue='size', data=tips, ax=axes[1,0]);

#total tip and day and size

sns.barplot(x='day', y='tip', hue='size', data=tips, ax=axes[1,1]);


#tip and day and time

sns.barplot(x='day', y='tip', hue='time', data=tips, ax=axes[1,2]);

# %%
### Pair plots with Seaborn

# %%
sns.pairplot(tips,hue='sex');

# %%
sns.pairplot(tips,hue='time');

# %%
sns.pairplot(tips,hue='smoker');
